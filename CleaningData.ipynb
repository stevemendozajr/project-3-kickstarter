# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Store filepath in a variable
data_import_full = "resources/properties_2017.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
data_df = pd.read_csv(data_import_full, encoding="ISO-8859-1")
# Out:
# /Users/Steve/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Show just the header
data_df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  5.0                    NaN
# 3          0.0         0.0                  3.0                    6.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# ...

# %%
to_drop = ['architecturalstyletypeid',
            'airconditioningtypeid',
            'architecturalstyletypeid',
            'basementsqft',
            'buildingclasstypeid',
            'decktypeid',
            'threequarterbathnbr',
            'finishedfloor1squarefeet',
            'finishedsquarefeet6',
            'finishedsquarefeet12',
            'finishedsquarefeet15',
            'finishedsquarefeet13',
            'finishedsquarefeet50',
            'fips',
            'fireplaceflag',
            'fullbathcnt',
            'garagetotalsqft',
            'hashottuborspa',
            'heatingorsystemtypeid',
            'poolsizesum',
            'pooltypeid10',
            'pooltypeid2',
            'pooltypeid7',
            'propertycountylandusecode',
            'propertylandusetypeid',
            'propertyzoningdesc',
            'rawcensustractandblock',
            'censustractandblock',
            'roomcnt',
            'storytypeid',
            'typeconstructiontypeid',
            'yardbuildingsqft17',
            'yardbuildingsqft26',
            'taxdelinquencyflag',
            'taxdelinquencyyear']

# %%
#deleting columns we dont want
data_df.drop(columns=to_drop, inplace=True)
data_df.head()
# Out:
#    bathroomcnt  bedroomcnt  buildingqualitytypeid  calculatedbathnbr  \
# 0          0.0         0.0                    NaN                NaN
# 1          0.0         0.0                    NaN                NaN
# 2          0.0         0.0                    NaN                NaN
# 3          0.0         0.0                    6.0                NaN
# 4          0.0         0.0                    NaN                NaN
#
#    calculatedfinishedsquarefeet  fireplacecnt  garagecarcnt    latitude  \
# 0                           NaN           NaN           NaN  34144442.0
# 1                           NaN           NaN           NaN  34140430.0
# 2                       73026.0           NaN           NaN  33989359.0
# 3                        5068.0           NaN           NaN  34148863.0
# 4                        1776.0           NaN           NaN  34194168.0
#
#      longitude  lotsizesquarefeet    ...      regionidneighborhood  \
# ...

# %%
#view which columns have null values
print(data_df.isnull().sum())
# Out:
# bathroomcnt                        2957
# bedroomcnt                         2945
# buildingqualitytypeid           1043822
# calculatedbathnbr                117156
# calculatedfinishedsquarefeet      45097
# fireplacecnt                    2672093
# garagecarcnt                    2094209
# latitude                           2932
# longitude                          2932
# lotsizesquarefeet                272706
# poolcnt                         2445585
# regionidcity                      62128
# regionidcounty                     2932
# regionidneighborhood            1828476
# regionidzip                       12714
# unitcnt                         1004175
# yearbuilt                         47833
# numberofstories                 2299541
# structuretaxvaluedollarcnt        46464
# taxvaluedollarcnt                 34266
# assessmentyear                     2933
# landtaxvaluedollarcnt             59926
# taxamount                         22752
# dtype: int64

# %%
data_df['buildingqualitytypeid'].value_counts()
# Out:
# 6.0     561502
# 8.0     501925
# 4.0     448049
# 7.0     190244
# 5.0     107053
# 9.0      69428
# 11.0     28488
# 3.0      17858
# 10.0     10629
# 12.0      4123
# 1.0       1776
# 2.0        320
# Name: buildingqualitytypeid, dtype: int64

# %%
data_df = data_df[data_df.buildingqualitytypeid.notnull()]
data_df.shape
# Out:
# (1941395, 23)

# %%
print(data_df.isnull().sum())
# Out:
# bathroomcnt                           0
# bedroomcnt                            0
# buildingqualitytypeid                 0
# calculatedbathnbr                 12687
# calculatedfinishedsquarefeet        101
# fireplacecnt                    1941395
# garagecarcnt                    1941386
# latitude                              0
# longitude                             0
# lotsizesquarefeet                 35632
# poolcnt                         1562033
# regionidcity                      35250
# regionidcounty                        0
# regionidneighborhood            1007953
# regionidzip                        2223
# unitcnt                            9027
# yearbuilt                          1965
# numberofstories                 1931712
# structuretaxvaluedollarcnt         3564
# taxvaluedollarcnt                   226
# assessmentyear                        0
# landtaxvaluedollarcnt               226
# taxamount                          3569
# dtype: int64
